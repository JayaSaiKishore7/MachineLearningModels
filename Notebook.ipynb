# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
df = pd.DataFrame({"Hours" :[1,2,3,4,5,6,7,8], "Marks":[10,20,30,40,50,60,70,80]}, index=[1,2,3,4,5,6,7,8])

# %%
##df= pd.read_csv("data.csv")

# %%
df.head()
# Out:
#    Hours  Marks
# 1      1     10
# 2      2     20
# 3      3     30
# 4      4     40
# 5      5     50

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, 1 to 8
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   8 non-null      int64
#  1   Marks   8 non-null      int64
# dtypes: int64(2)
# memory usage: 192.0 bytes

# %%
df.shape
# Out:
# (8, 2)

# %%
df.describe()
# Out:
#          Hours      Marks
# count  8.00000   8.000000
# mean   4.50000  45.000000
# std    2.44949  24.494897
# min    1.00000  10.000000
# 25%    2.75000  27.500000
# 50%    4.50000  45.000000
# 75%    6.25000  62.500000
# max    8.00000  80.000000

# %%
df.isnull().sum()
# Out:
# Hours    0
# Marks    0
# dtype: int64

# %%
x = df[["Hours"]]
y = df["Marks"]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.scatterplot(x="Hours", y="Marks", data=df)
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.25, random_state=42)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train, y_test = train_test_split(x,y, random_state = 42,test_size = 0.20)
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_train_prd = model.predict(x_train)
y_test_prd = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
mse_train = mean_squared_error(y_train, y_train_pred)
mse_test = mean_squared_error(y_test, y_test_pred)
print("Training MSE:", mse_train)
print("Testing MSE:", mse_test)
# Out:
# Training MSE: 3.3658065289429835e-29
# Testing MSE: 5.048709793414476e-29

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
import numpy as np

# %%
mae_train = mean_absolute_error(y_train, y_train_pred)
mae_test  = mean_absolute_error(y_test, y_test_pred)

print("Training MAE:", mae_train)
print("Testing MAE:", mae_test)
# Out:
# Training MAE: 4.736951571734001e-15
# Testing MAE: 7.105427357601002e-15

# %%
rmse_train = np.sqrt(mse_train)
rmse_test  = np.sqrt(mse_test)

print("Training RMSE:", rmse_train)
print("Testing RMSE:", rmse_test)
# Out:
# Training RMSE: 5.801557143511545e-15
# Testing RMSE: 7.105427357601002e-15

# %%
r2_train = r2_score(y_train, y_train_pred)
r2_test  = r2_score(y_test, y_test_pred)

print("Training R²:", r2_train)
print("Testing R²:", r2_test)
# Out:
# Training R²: 1.0
# Testing R²: 1.0

# %%
residuals = y_test - y_test_pred
print(residuals)
# Out:
# 2    7.105427e-15
# 6    7.105427e-15
# Name: Marks, dtype: float64

# %%
new_hours = [[7]]
predicted_marks = model.predict(new_hours)

print("Predicted Marks for 7 hours:", predicted_marks[0])
# Out:
# Predicted Marks for 7 hours: 70.0
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
